# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    "Name" : ["Santosh", "Raju"],
    "Cgpa" : [8.4, 6.5]
})

# %%
df
# Out:
#       Name  Cgpa
# 0  Santosh   8.4
# 1     Raju   6.5

# %%
print(df)
# Out:
#       Name  Cgpa
# 0  Santosh   8.4
# 1     Raju   6.5

# %% [markdown]
# <h1>Series</h1>

# %%
s = pd.Series([23, 21, 43, 55])
print(s)
# Out:
# 0    23
# 1    21
# 2    43
# 3    55
# dtype: int64

# %%
print(type(s))
# Out:
# <class 'pandas.Series'>

# %%
print(s[0])
print(s[1])
# Out:
# 23
# 21

# %%
print(s.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s2 = pd.Series([23, 24, 55, 64], index = ["Santosh", "Raju", "Nitish", "Chhotu"])
print(s2["Santosh"])
print(s2["Nitish"])
print(s2)
# Out:
# 23
# 55
# Santosh    23
# Raju       24
# Nitish     55
# Chhotu     64
# dtype: int64

# %%
s1 = pd.Series([1,2,3])
s2 = pd.Series([4,5,6])

print(s1 + s2)
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64
